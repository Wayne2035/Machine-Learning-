# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Breast Cancer Case Study

# %% [markdown]
#  1. Using LogisticRegression

# %%
data = pd.read_csv("/content/breast-cancer.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.isnull().sum()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
x = data.drop(columns = ["diagnosis", "id"])

# %%
y = data["diagnosis"]

# %%
x.corr()

# %%
## indentifying and dropping highly correlated features

# %%
corr_matrix = x.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

to_drop = [col for col in upper.columns if any(upper[col] > 0.85)]
x = x.drop(columns=to_drop)
print("Dropped:", to_drop)
# Out:
# Dropped: []

# %%
x.shape
# Out:
# (569, 17)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x= pd.DataFrame(x)

# %%
x.head()
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.965034965034965

# %%
confusion_matrix(y_test, y_pred)
pd.DataFrame(confusion_matrix(y_test, y_pred))
# Out:
#     0   1
# 0  86   3
# 1   2  52

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           B       0.98      0.97      0.97        89\n           M       0.95      0.96      0.95        54\n\n    accuracy                           0.97       143\n   macro avg       0.96      0.96      0.96       143\nweighted avg       0.97      0.97      0.97       143\n'

# %%
report = pd.DataFrame(classification_report(y_test, y_pred, output_dict = True))

# %%
report
# Out:
#                    B          M  accuracy   macro avg  weighted avg
# precision   0.977273   0.945455  0.965035    0.961364      0.965257
# recall      0.966292   0.962963  0.965035    0.964628      0.965035
# f1-score    0.971751   0.954128  0.965035    0.962940      0.965097
# support    89.000000  54.000000  0.965035  143.000000    143.000000

# %% [markdown]
# 2. Using KNN Algorithem

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model1 = KNeighborsClassifier()

# %%
model1.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_k = model1.predict(x_test)

# %%
print("accuracy score is:",accuracy_score(y_test, y_pred_k))
# Out:
# accuracy score is: 0.9370629370629371

# %%
confusion_matrix(y_test, y_pred_k)
# Out:
# array([[85,  4],
#        [ 5, 49]])

# %%
pd.DataFrame(confusion_matrix(y_test, y_pred_k))
# Out:
#     0   1
# 0  85   4
# 1   5  49

# %%
classification_report(y_test, y_pred_k)
# Out:
# '              precision    recall  f1-score   support\n\n           B       0.94      0.96      0.95        89\n           M       0.92      0.91      0.92        54\n\n    accuracy                           0.94       143\n   macro avg       0.93      0.93      0.93       143\nweighted avg       0.94      0.94      0.94       143\n'

# %%
report_k = pd.DataFrame(classification_report(y_test, y_pred_k, output_dict = True))

# %%
report_k
# Out:
#                    B          M  accuracy   macro avg  weighted avg
# precision   0.944444   0.924528  0.937063    0.934486      0.936924
# recall      0.955056   0.907407  0.937063    0.931232      0.937063
# f1-score    0.949721   0.915888  0.937063    0.932804      0.936945
# support    89.000000  54.000000  0.937063  143.000000    143.000000

# %% [markdown]
# 3. Using DecisionTree model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier()

# %%
model2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_T =model2. predict(x_test)

# %%
accuracy_score(y_test, y_pred_T)
# Out:
# 0.916083916083916

# %%
report = pd.DataFrame(classification_report(y_test, y_pred_T, output_dict = True))

# %%
report
# Out:
#                    B          M  accuracy   macro avg  weighted avg
# precision   0.975309   0.838710  0.916084    0.907009      0.923726
# recall      0.887640   0.962963  0.916084    0.925302      0.916084
# f1-score    0.929412   0.896552  0.916084    0.912982      0.917003
# support    89.000000  54.000000  0.916084  143.000000    143.000000

# %% [markdown]
# 3. Using Random Forest model
